# %% [markdown]
# # Healthcare Lab (Regression)

# %% [markdown]
# **Learning Objectives:**
#   * Define and fit regression using ML techniques
#   * Gain exposure to healthcare related DataSets

# %% [markdown]
# ## Context of the dataset
#
# ### 1. The dataset is consisted of records corresponding to medical events.
# ### 2. Each medical event is uniquely identified by `MedicalClaim`.
# ### 3. A given medical event might involve several medical procedures.
# ### 4. Each medical procedure is uniquely identified by `ClaimItem`
# ### 5. A given medical procedure is characterized by `PrincipalDiagnosisDesc`,`PrincipalDiagnosis`,`RevenueCodeDesc`, `RevenueCode`, `TypeFlag` and `TotalExpenses`
#
# ### 6. Each medical procedure involves: `MemberName`,`MemberID`,`County`,`HospitalName`, `HospitalType`, `StartDate`,`EndDate`

# %% [markdown]
# ## 1. Library Import

# %%
from packaging import version
import sklearn

assert version.parse(sklearn.__version__) >= version.parse("1.0.1")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import learning_curve
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.preprocessing import PolynomialFeatures

from sklearn.model_selection import cross_validate
from sklearn.metrics import r2_score, mean_squared_error

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Data loading and DataFrame creation

# %%
HealthCareDataSet=pd.read_csv("https://github.com/thousandoaks/Python4DS-I/raw/main/datasets/HealthcareDataset_PublicRelease.csv",sep=',',parse_dates=['StartDate','EndDate','BirthDate'])

# %%
HealthCareDataSet.head(3)
# Out:
#        Id MemberName  MemberID    County      MedicalClaim  ClaimItem  \
# 0  634363   e659f3f4  6a380a28  6f943458  c1e3436737c77899         18
# 1  634364   e659f3f4  6a380a28  6f943458  c1e3436737c77899         21
# 2  634387   e659f3f4  6a380a28  6f943458  c1e3436737c77899         10
#
#   HospitalName HospitalType  StartDate    EndDate PrincipalDiagnosisDesc  \
# 0     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 1     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 2     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
#
#   PrincipalDiagnosis                                    RevenueCodeDesc  \
# 0             R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 1             R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 2             R10.13       LABORATORY - CLINICAL DIAGNOSTIC: HEMATOLOGY
#
#    RevenueCode TypeFlag  BirthDate  TotalExpenses
# 0        636.0       ER 1967-05-13         15.148
# 1        636.0       ER 1967-05-13          3.073
# 2        305.0       ER 1967-05-13        123.900

# %%
HealthCareDataSet.describe()
# Out:
#                   Id     ClaimItem                      StartDate  \
# count   52563.000000  52563.000000                          52563
# mean   685655.197953     12.023990  2020-06-21 00:12:27.902516992
# min    634363.000000      1.000000            2020-01-01 00:00:00
# 25%    658574.500000      5.000000            2020-03-09 00:00:00
# 50%    684404.000000     10.000000            2020-06-22 00:00:00
# 75%    712375.500000     16.000000            2020-09-25 00:00:00
# max    741736.000000    127.000000            2020-12-31 00:00:00
# std     30913.839360     10.747558                            NaN
#
#                              EndDate   RevenueCode  \
# count                          52563  52563.000000
# mean   2020-06-24 21:03:58.958963200    386.321995
# min              2020-01-01 00:00:00     24.000000
# 25%              2020-03-13 00:00:00    301.000000
# 50%              2020-06-26 00:00:00    307.000000
# 75%              2020-09-29 00:00:00    450.000000
# max              2020-12-31 00:00:00    942.000000
# std                              NaN    158.551733
#
#                            BirthDate  TotalExpenses
# count                          52563   52563.000000
# mean   1948-05-11 14:05:37.378003712    2735.230373
# min              1921-01-18 00:00:00       0.000000
# 25%              1939-11-10 00:00:00     194.642000
# 50%              1947-05-12 00:00:00     675.262000
# 75%              1953-12-02 00:00:00    2309.265000
# max              1999-08-09 00:00:00  504533.400000
# std                              NaN    8292.178928

# %%
HealthCareDataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52563 entries, 0 to 52562
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      52563 non-null  int64
#  1   MemberName              52563 non-null  object
#  2   MemberID                52563 non-null  object
#  3   County                  52563 non-null  object
#  4   MedicalClaim            52563 non-null  object
#  5   ClaimItem               52563 non-null  int64
#  6   HospitalName            52563 non-null  object
#  7   HospitalType            52563 non-null  object
#  8   StartDate               52563 non-null  datetime64[ns]
#  9   EndDate                 52563 non-null  datetime64[ns]
#  10  PrincipalDiagnosisDesc  52563 non-null  object
#  11  PrincipalDiagnosis      52563 non-null  object
#  12  RevenueCodeDesc         52561 non-null  object
#  13  RevenueCode             52563 non-null  float64
#  14  TypeFlag                52563 non-null  object
#  15  BirthDate               52563 non-null  datetime64[ns]
#  16  TotalExpenses           52563 non-null  float64
# dtypes: datetime64[ns](3), float64(2), int64(2), object(10)
# memory usage: 6.8+ MB

# %%
HealthCareDataSet['AgeAtMedicalEvent']=(HealthCareDataSet['StartDate']-HealthCareDataSet['BirthDate'])

# %%
HealthCareDataSet['AgeAtMedicalEvent'].dt.total_seconds() / (365.25 * 24 * 60 * 60)
# Out:
# 0        52.657084
# 1        52.657084
# 2        52.657084
# 3        52.657084
# 4        52.657084
#            ...
# 52558    80.637919
# 52559    70.258727
# 52560    70.258727
# 52561    70.258727
# 52562    70.258727
# Name: AgeAtMedicalEvent, Length: 52563, dtype: float64

# %%
HealthCareDataSet['AgeAtMedicalEvent']=HealthCareDataSet['AgeAtMedicalEvent'].dt.total_seconds() / (365.25 * 24 * 60 * 60)

# %%
## We need to compute the duration of each Medical Treatment
HealthCareDataSet['MedicalTreatmentDuration']=(HealthCareDataSet['EndDate']-HealthCareDataSet['StartDate']).dt.days

# %%
HealthCareDataSet.groupby('County').count()
# Out:
#              Id  MemberName  MemberID  MedicalClaim  ClaimItem  HospitalName  \
# County
# 02af982d  23525       23525     23525         23525      23525         23525
# 217dc01f     59          59        59            59         59            59
# 33b7d74d      1           1         1             1          1             1
# 39825de7    165         165       165           165        165           165
# 425a37b2   9468        9468      9468          9468       9468          9468
# 5597ffc0    443         443       443           443        443           443
# 6f0b5b6c    555         555       555           555        555           555
# 6f943458   1849        1849      1849          1849       1849          1849
# 7a56b047      7           7         7             7          7             7
# 7d9b432e    838         838       838           838        838           838
# 89e38653   3767        3767      3767          3767       3767          3767
# adb3fb00    466         466       466           466        466           466
# b021dd12   2679        2679      2679          2679       2679          2679
# b60a20c4     27          27        27            27         27            27
# bd284e56     15          15        15            15         15            15
# e6708950   1613        1613      1613          1613       1613          1613
# ea48569b   1367        1367      1367          1367       1367          1367
# fc471384    370         370       370           370        370           370
# fd218584   5349        5349      5349          5349       5349          5349
#
#           HospitalType  StartDate  EndDate  PrincipalDiagnosisDesc  \
# County
# 02af982d         23525      23525    23525                   23525
# 217dc01f            59         59       59                      59
# 33b7d74d             1          1        1                       1
# 39825de7           165        165      165                     165
# 425a37b2          9468       9468     9468                    9468
# 5597ffc0           443        443      443                     443
# 6f0b5b6c           555        555      555                     555
# 6f943458          1849       1849     1849                    1849
# 7a56b047             7          7        7                       7
# 7d9b432e           838        838      838                     838
# 89e38653          3767       3767     3767                    3767
# adb3fb00           466        466      466                     466
# b021dd12          2679       2679     2679                    2679
# b60a20c4            27         27       27                      27
# bd284e56            15         15       15                      15
# e6708950          1613       1613     1613                    1613
# ea48569b          1367       1367     1367                    1367
# fc471384           370        370      370                     370
# fd218584          5349       5349     5349                    5349
#
#           PrincipalDiagnosis  RevenueCodeDesc  RevenueCode  TypeFlag  \
# County
# 02af982d               23525            23525        23525     23525
# 217dc01f                  59               59           59        59
# 33b7d74d                   1                1            1         1
# 39825de7                 165              165          165       165
# 425a37b2                9468             9468         9468      9468
# 5597ffc0                 443              443          443       443
# 6f0b5b6c                 555              555          555       555
# 6f943458                1849             1849         1849      1849
# 7a56b047                   7                7            7         7
# 7d9b432e                 838              838          838       838
# 89e38653                3767             3767         3767      3767
# adb3fb00                 466              466          466       466
# b021dd12                2679             2679         2679      2679
# b60a20c4                  27               27           27        27
# bd284e56                  15               15           15        15
# e6708950                1613             1611         1613      1613
# ea48569b                1367             1367         1367      1367
# fc471384                 370              370          370       370
# fd218584                5349             5349         5349      5349
#
#           BirthDate  TotalExpenses  AgeAtMedicalEvent  \
# County
# 02af982d      23525          23525              23525
# 217dc01f         59             59                 59
# 33b7d74d          1              1                  1
# 39825de7        165            165                165
# 425a37b2       9468           9468               9468
# 5597ffc0        443            443                443
# 6f0b5b6c        555            555                555
# 6f943458       1849           1849               1849
# 7a56b047          7              7                  7
# 7d9b432e        838            838                838
# 89e38653       3767           3767               3767
# adb3fb00        466            466                466
# b021dd12       2679           2679               2679
# b60a20c4         27             27                 27
# bd284e56         15             15                 15
# e6708950       1613           1613               1613
# ea48569b       1367           1367               1367
# fc471384        370            370                370
# fd218584       5349           5349               5349
#
#           MedicalTreatmentDuration
# County
# 02af982d                     23525
# 217dc01f                        59
# 33b7d74d                         1
# 39825de7                       165
# 425a37b2                      9468
# 5597ffc0                       443
# 6f0b5b6c                       555
# 6f943458                      1849
# 7a56b047                         7
# 7d9b432e                       838
# 89e38653                      3767
# adb3fb00                       466
# b021dd12                      2679
# b60a20c4                        27
# bd284e56                        15
# e6708950                      1613
# ea48569b                      1367
# fc471384                       370
# fd218584                      5349

# %%
HealthCareDataSet.groupby('TypeFlag').count()
# Out:
#              Id  MemberName  MemberID  County  MedicalClaim  ClaimItem  \
# TypeFlag
# ER        23978       23978     23978   23978         23978      23978
# INP       28585       28585     28585   28585         28585      28585
#
#           HospitalName  HospitalType  StartDate  EndDate  \
# TypeFlag
# ER               23978         23978      23978    23978
# INP              28585         28585      28585    28585
#
#           PrincipalDiagnosisDesc  PrincipalDiagnosis  RevenueCodeDesc  \
# TypeFlag
# ER                         23978               23978            23978
# INP                        28585               28585            28583
#
#           RevenueCode  BirthDate  TotalExpenses  AgeAtMedicalEvent  \
# TypeFlag
# ER              23978      23978          23978              23978
# INP             28585      28585          28585              28585
#
#           MedicalTreatmentDuration
# TypeFlag
# ER                           23978
# INP                          28585

# %% [markdown]
# ### 3. Cost Predictor (Patient unit of analysis)
# #### We need to try to predict expected costs for any given medical intervention
# #### We will consider the following features: ['County','Age','Duration','Principal Diagnosis','TypeFlag'] with 'TotalExpenses' as the reponse variable.

# %% [markdown]
# #### We aggregate all Claim Items associated to a specific Medical Claim

# %%
HealthCareDataSetGroupedByMedicalClaim=HealthCareDataSet.groupby(['MemberID','County','MedicalClaim','PrincipalDiagnosis','TypeFlag','AgeAtMedicalEvent','MedicalTreatmentDuration']).agg({'TotalExpenses':'sum'}).reset_index()
HealthCareDataSetGroupedByMedicalClaim
# Out:
#       MemberID    County      MedicalClaim PrincipalDiagnosis TypeFlag  \
# 0     00024834  adb3fb00  24a081d0f754e53e           S72.142A      INP
# 1     00024834  adb3fb00  4b5a15fb93cd31ba             K74.69      INP
# 2     00198770  425a37b2  42efad506c7fa1a2                R05       ER
# 3     004980c9  fd218584  c3c31f9339fef298           S98.112A      INP
# 4     004d7fd0  ea48569b  e64af0c1c6887443              E86.0       ER
# ...        ...       ...               ...                ...      ...
# 3356  fee15f24  02af982d  bee070b6550ba6b3             R07.89       ER
# 3357  ff3c17df  adb3fb00  7bb641881f53aca0             M17.11      INP
# 3358  ff64d58b  02af982d  0ae12c3b63e8c251           S68.121A       ER
# 3359  ff64d58b  02af982d  7f1919675967fceb           S68.621A       ER
# 3360  ffbd7858  02af982d  a855bf1f9b8b6022              U07.1       ER
#
#       AgeAtMedicalEvent  MedicalTreatmentDuration  TotalExpenses
# 0             88.158795                         7     158558.610
# 1             88.216290                         7     109266.528
# 2             62.770705                         0       5725.587
# 3             72.780287                         7     172035.920
# 4             88.936345                         0       1821.890
# ...                 ...                       ...            ...
# 3356          79.682409                         1      35701.561
# 3357          81.946612                         1      91724.941
# 3358          69.081451                         0       5034.834
# 3359          69.081451                         0      10374.301
# 3360          99.400411                         1       5300.631
#
# [3361 rows x 8 columns]

# %% [markdown]
# ### 4. First model (Linear model)

# %%
# Choose target and features
y = HealthCareDataSetGroupedByMedicalClaim['TotalExpenses']

features = ['County', 'PrincipalDiagnosis','TypeFlag','AgeAtMedicalEvent','MedicalTreatmentDuration']
X = HealthCareDataSetGroupedByMedicalClaim[features]

# %%
X
# Out:
#         County PrincipalDiagnosis TypeFlag  AgeAtMedicalEvent  \
# 0     adb3fb00           S72.142A      INP          88.158795
# 1     adb3fb00             K74.69      INP          88.216290
# 2     425a37b2                R05       ER          62.770705
# 3     fd218584           S98.112A      INP          72.780287
# 4     ea48569b              E86.0       ER          88.936345
# ...        ...                ...      ...                ...
# 3356  02af982d             R07.89       ER          79.682409
# 3357  adb3fb00             M17.11      INP          81.946612
# 3358  02af982d           S68.121A       ER          69.081451
# 3359  02af982d           S68.621A       ER          69.081451
# 3360  02af982d              U07.1       ER          99.400411
#
#       MedicalTreatmentDuration
# 0                            7
# 1                            7
# 2                            0
# 3                            7
# 4                            0
# ...                        ...
# 3356                         1
# 3357                         1
# 3358                         0
# 3359                         0
# 3360                         1
#
# [3361 rows x 5 columns]

# %% [markdown]
# #### 4.1. Encoding of categorical features
#
# Our Dataset has categorical features
#  We nee to code them before fitting any model

# %%
# Identify categorical features
categorical_features = X.select_dtypes(include=['object']).columns # Select columns with 'object' dtype
categorical_features
# Out:
# Index(['County', 'PrincipalDiagnosis', 'TypeFlag'], dtype='object')

# %%
# Create an OrdinalEncoder
enc = OrdinalEncoder()

# %%
# Fit and transform the categorical features
X[categorical_features] = enc.fit_transform(X[categorical_features])
X
# Out:
#       County  PrincipalDiagnosis  TypeFlag  AgeAtMedicalEvent  \
# 0       11.0               871.0       1.0          88.158795
# 1       11.0               420.0       1.0          88.216290
# 2        4.0               606.0       0.0          62.770705
# 3       18.0               934.0       1.0          72.780287
# 4       16.0                93.0       0.0          88.936345
# ...      ...                 ...       ...                ...
# 3356     0.0               615.0       0.0          79.682409
# 3357    11.0               485.0       1.0          81.946612
# 3358     0.0               853.0       0.0          69.081451
# 3359     0.0               855.0       0.0          69.081451
# 3360     0.0              1009.0       0.0          99.400411
#
#       MedicalTreatmentDuration
# 0                            7
# 1                            7
# 2                            0
# 3                            7
# 4                            0
# ...                        ...
# 3356                         1
# 3357                         1
# 3358                         0
# 3359                         0
# 3360                         1
#
# [3361 rows x 5 columns]

# %% [markdown]
# #### 4.2. Dataset Split

# %%
# split data into training and test data, for both features and target
# The split is based on a random number generator. Supplying a numeric value to
# the random_state argument guarantees we get the same split every time we
# run this script.
train_X, test_X, train_y, test_y = train_test_split(X, y, random_state = 0)

# %%
train_X.head()
# Out:
#       County  PrincipalDiagnosis  TypeFlag  AgeAtMedicalEvent  \
# 1190     9.0               146.0       0.0          39.841205
# 745      0.0               110.0       0.0          73.500342
# 1853     0.0               538.0       1.0          81.738535
# 2795     7.0                67.0       1.0          83.961670
# 411      0.0                78.0       1.0          55.030801
#
#       MedicalTreatmentDuration
# 1190                         0
# 745                          0
# 1853                         3
# 2795                         6
# 411                          3

# %% [markdown]
# #### 4.3 Model fit

# %%
# Model fitting
linear_model = LinearRegression()
linear_model.fit(train_X, train_y)
# Out:
# LinearRegression()

# %% [markdown]
# #### 4.4. Model evaluation

# %%
# Make predictions on the test set
predictions = linear_model.predict(test_X)

# %%
## Model evaluation

print(mean_absolute_error(test_y, predictions))
# Out:
# 21214.054229135145

# %% [markdown]
# #### 4.5 Cross validation

# %%
# prompt: cross validate the model

# Perform cross-validation
cv_results = cross_validate(linear_model, X, y, cv=5, scoring=('r2', 'neg_mean_squared_error'))

# Print the results
print("Cross-validation R^2 scores:", cv_results['test_r2'])
print("Cross-validation MSE scores:", -cv_results['test_neg_mean_squared_error'])
print("Mean R^2:", np.mean(cv_results['test_r2']))
print("Mean MSE:", -np.mean(cv_results['test_neg_mean_squared_error']))
# Out:
# Cross-validation R^2 scores: [0.62680939 0.73917029 0.47882663 0.56133314 0.53674956]
# Cross-validation MSE scores: [2.43205119e+09 1.94869656e+09 1.80137621e+09 1.74639891e+09
#  1.17920461e+09]
# Mean R^2: 0.5885778032374295
# Mean MSE: 1821545497.3746803

# %%
train_sizes, train_scores, valid_scores = learning_curve(
    LinearRegression(), X, y, train_sizes=np.linspace(0.01, 1.0, 40),
    scoring="neg_root_mean_squared_error")
train_errors = -train_scores.mean(axis=1)
valid_errors = -valid_scores.mean(axis=1)

# %%
plt.figure(figsize=(6, 4))  # extra code – not needed, just formatting
plt.plot(train_sizes, train_errors, "r-+", linewidth=2, label="train")
plt.plot(train_sizes, valid_errors, "b-", linewidth=3, label="test")

plt.xlabel("Training set size")
plt.ylabel("RMSE")
plt.grid()
plt.legend(loc="upper right")
plt.yscale('log') # Set y-axis to log scale

#plt.axis([-100, 20000, 40000, 120000])

plt.show()

# %%
# prompt: previous plot y axis in log scale

train_sizes, train_scores, valid_scores = learning_curve(
    LinearRegression(), X, y, train_sizes=np.linspace(0.01, 1.0, 40),
    scoring="neg_root_mean_squared_error")
train_errors = -train_scores.mean(axis=1)
valid_errors = -valid_scores.mean(axis=1)
plt.figure(figsize=(6, 4))  # extra code – not needed, just formatting
plt.plot(train_sizes, train_errors, "r-+", linewidth=2, label="train")
plt.plot(train_sizes, valid_errors, "b-", linewidth=3, label="test")

plt.xlabel("Training set size")
plt.ylabel("RMSE")
plt.grid()
plt.legend(loc="upper right")

#plt.axis([-100, 20000, 40000, 120000])
plt.yscale('log') # Set y-axis to log scale
plt.show()

# %% [markdown]
# #### Based on the figure above we conclude that the first linear model is underfitting.
# #### To see why, first let’s look at the training error. When there are just one or two instances in the training set, the model can fit them perfectly, which is why the curve starts at zero (low RMSE).But as new instances are added to the training set, it becomes impossible for the model to fit the training data perfectly, probably because the data is noisy and because it is not linear at all.
#
#
# #### So the error on the training data goes up until it reaches a plateau, at which point adding new instances to the training set doesn’t make the average error much better (or worse).
#
# #### These learning curves are typical of a model that’s underfitting. Both curves have reached a plateau; they are close to each other; both remain at large error levels.

# %% [markdown]
# ### 5. Second model (Polynomial model )
#
# #### Given the limitations of the previous model we try adding second order terms

# %%
# Add quadratic elements

poly_features = PolynomialFeatures(degree=5, include_bias=False)
X_poly = poly_features.fit_transform(X)

# %%
linear_model = LinearRegression()

# %% [markdown]
# ### 5.1. Cross validation

# %%
# prompt: cross validate the model

# Perform cross-validation
cv_results = cross_validate(linear_model, X_poly, y, cv=5, scoring=('r2', 'neg_mean_squared_error'))

# Print the results
print("Cross-validation R^2 scores:", cv_results['test_r2'])
print("Cross-validation MSE scores:", -cv_results['test_neg_mean_squared_error'])
print("Mean R^2:", np.mean(cv_results['test_r2']))
print("Mean MSE:", -np.mean(cv_results['test_neg_mean_squared_error']))
# Out:
# Cross-validation R^2 scores: [-8.08349057e+00 -2.30140773e+05 -5.60834574e-01 -1.46991001e+01
#   6.87190726e-02]
# Cross-validation MSE scores: [5.91963291e+10 1.71942257e+15 5.39484643e+09 6.25004845e+10
#  2.37057683e+09]
# Mean R^2: -46032.809623177716
# Mean MSE: 343910406314192.94

# %% [markdown]
# #### 5.2 Learning Curves

# %%
train_sizes, train_scores, valid_scores = learning_curve(
    LinearRegression(), X_poly, y, train_sizes=np.linspace(0.01, 1.0, 40),
    scoring="neg_root_mean_squared_error")
train_errors = -train_scores.mean(axis=1)
valid_errors = -valid_scores.mean(axis=1)

# %%
plt.figure(figsize=(6, 4))  # extra code – not needed, just formatting
plt.plot(train_sizes, train_errors, "r-+", linewidth=2, label="train")
plt.plot(train_sizes, valid_errors, "b-", linewidth=3, label="test")

plt.xlabel("Training set size")
plt.ylabel("RMSE")
plt.grid()
plt.legend(loc="upper right")
plt.yscale('log') # Set y-axis to log scale

#plt.axis([-100, 20000, 40000, 120000])

plt.show()

# %% [markdown]
# #### Based on the previous figure we conclude that this fifth-order polynomial model does not improve the previous model. On the one hand the training error remains high as we increase the training size. On the other hand the test error is always larger that the training error, this indicates that the level is overfitting (it adapts too much to the training data and is unable to perform well with previously not seen data)
